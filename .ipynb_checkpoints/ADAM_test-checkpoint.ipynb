# %%
print("Hello, ADAM Robot!")
# Out:
# Hello, ADAM Robot!

# %%
print("How are you ADAM.......!")
# Out:
# How are you ADAM.......!

# %%
print('Have a great day !')
# Out:
# Have a great day !

# %%
print("Starting robot...")
for i in range (3):
    print(f"Step {i+1}")
print("ADAM is ready")
# Out:
# Starting robot...
# Step 1
# Step 2
# Step 3
# ADAM is ready
